# %% [markdown]
# # Exploración de los datos

# %% [markdown]
# ## 1. Importar las librerías

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn

# %% [markdown]
# ## 2. Cargar datos

# %% [markdown]
# Cargar los datos del csv

# %%
datos_pacientes = pd.read_csv('./data/Datos Lab 1.csv', )

# %% [markdown]
# Trabajar sobre una copia de los datos

# %%
datos = datos_pacientes.copy()

# %% [markdown]
# ## 3. Perfilamiento

# %% [markdown]
# Se usa la función head() para tomar una muestra de los primero datos y obtener una visión inicial.

# %%
datos.head()
# Out:
#   Patient ID    Date of Service Sex   Age  Weight (kg)  Height (m)     BMI  \
# 0   isDx5313  November 08, 2023   M  44.0      114.300       1.720  38.600
# 1   LHCK2961         20/03/2024   F  57.0       92.923       1.842  33.116
# 2   WjVn1699         2021-05-27   F   NaN       73.400       1.650  27.000
# 3   dCDO1109     April 18, 2022   F  35.0      113.300       1.780  35.800
# 4   pnpE1080         01/11/2024   F  48.0      102.200       1.750  33.400
#
#    Abdominal Circumference (cm) Blood Pressure (mmHg)  \
# 0                       100.000                112/83
# 1                       106.315                101/91
# 2                        78.100                 90/74
# 3                        79.600                 92/89
# 4                       106.700                121/68
#
#    Total Cholesterol (mg/dL)  ...  Physical Activity Level  \
# 0                      228.0  ...                     High
# 1                      158.0  ...                     High
# 2                      135.0  ...                     High
# 3                      158.0  ...                 Moderate
# 4                      207.0  ...                      Low
#
#    Family History of CVD Height (cm) Waist-to-Height Ratio Systolic BP  \
# 0                      N     172.000                 0.581       112.0
# 1                      Y     184.172                 0.577       101.0
# 2                      N     165.000                 0.473        90.0
# 3                      Y     178.000                 0.447        92.0
# 4                      Y     175.000                 0.610       121.0
#
#   Diastolic BP  Blood Pressure Category  Estimated LDL (mg/dL)  \
# 0         83.0     Hypertension Stage 1                  121.0
# 1         91.0     Hypertension Stage 2                   57.0
# 2         74.0                   Normal                   45.0
# 3         89.0     Hypertension Stage 1                   94.0
# 4         68.0                 Elevated                  128.0
#
#    CVD Risk Score  CVD Risk Level
# 0          19.880            HIGH
# 1          16.833    INTERMEDIARY
# 2          12.600             LOW
# 3          14.920            HIGH
# 4          18.870            HIGH
#
# [5 rows x 24 columns]

# %% [markdown]
# También se pueden observar datos aleatorios del dataset para asegurarse que otras posiciones cumplen con el formato.

# %%
display(datos.sample(10))
# Out:
#      Patient ID    Date of Service Sex   Age  Weight (kg)  Height (m)     BMI  \
# 1267   rETH6271          24 Dec 24   M  39.0       64.100       1.700  22.200
# 1373   KmWR1254         28/03/2024   F  57.0      118.900       1.890  33.300
# 813    lTUG4850         2020-09-09   M  50.0      110.317       1.852  33.401
# 874    TObL7108         01-18-2021   M  56.0       55.400       1.870  15.800
# 306    Qbvz4402          11 Jul 20   F  55.0      115.300         NaN  32.300
# 1405   vYLW1606         2020-09-23   M  68.0          NaN       1.851  20.474
# 146    lyjE0672   January 13, 2022   F  42.0      104.100       1.880  29.500
# 576    toIX9000  November 11, 2022   M  45.0       91.300       1.870  26.100
# 1374   TDFh4321         07-30-2021   F  69.0      108.428       1.579  30.689
# 964    rOMu6070         06-19-2023   M  71.0       86.264       1.694  29.423
#
#       Abdominal Circumference (cm) Blood Pressure (mmHg)  \
# 1267                        99.100                113/69
# 1373                        76.700                147/74
# 813                        100.033                110/90
# 874                         99.100                124/78
# 306                         85.600                113/98
# 1405                        97.393                160/99
# 146                         83.400                132/86
# 576                         80.000                102/61
# 1374                        75.798               122/112
# 964                        119.233                170/62
#
#       Total Cholesterol (mg/dL)  ...  Physical Activity Level  \
# 1267                      175.0  ...                 Moderate
# 1373                      193.0  ...                 Moderate
# 813                         NaN  ...                     High
# 874                       209.0  ...                     High
# 306                       192.0  ...                      Low
# 1405                      279.0  ...                     High
# 146                       196.0  ...                      Low
# 576                       271.0  ...                     High
# 1374                      159.0  ...                 Moderate
# 964                       204.0  ...                     High
#
#       Family History of CVD Height (cm) Waist-to-Height Ratio Systolic BP  \
# 1267                      Y     170.000                 0.583       113.0
# 1373                      N     189.000                 0.406       147.0
# 813                       Y     185.168                 0.540       110.0
# 874                       N     187.000                 0.530       124.0
# 306                       Y         NaN                 0.453       113.0
# 1405                      Y     185.117                 0.526       160.0
# 146                       Y     188.000                   NaN       132.0
# 576                       N     187.000                 0.428       102.0
# 1374                      N     157.940                 0.480       122.0
# 964                       Y         NaN                 0.704       170.0
#
#      Diastolic BP  Blood Pressure Category  Estimated LDL (mg/dL)  \
# 1267         69.0                   Normal                   90.0
# 1373         74.0     Hypertension Stage 2                  120.0
# 813          90.0     Hypertension Stage 2                  158.0
# 874          78.0                 Elevated                  141.0
# 306          98.0     Hypertension Stage 2                  107.0
# 1405         99.0     Hypertension Stage 2                    NaN
# 146          86.0     Hypertension Stage 1                   98.0
# 576          61.0                   Normal                  210.0
# 1374        112.0     Hypertension Stage 2                   40.0
# 964           NaN     Hypertension Stage 2                  109.0
#
#       CVD Risk Score  CVD Risk Level
# 1267          13.590    INTERMEDIARY
# 1373          17.870    INTERMEDIARY
# 813           19.680    INTERMEDIARY
# 874           13.540    INTERMEDIARY
# 306           17.950            HIGH
# 1405          17.675    INTERMEDIARY
# 146           16.420            HIGH
# 576           17.740            HIGH
# 1374          17.418            HIGH
# 964           18.465    INTERMEDIARY
#
# [10 rows x 24 columns]

# %% [markdown]
# Usando datos.shape se puede conocer información general sobre la cantidad de registros y variables:

# %%
datos.shape
# Out:
# (1639, 24)

# %% [markdown]
# Existen 1639 registros. Para cada uno de esos registros hay 24 variables que se deben tener en cuenta.

# %% [markdown]
# Para saber información específica sobre el tipo de dato de cada una de las variables se puede hacer lo siguiente:

# %%
datos.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1639 entries, 0 to 1638
# Data columns (total 24 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Patient ID                    1639 non-null   str
#  1   Date of Service               1639 non-null   str
#  2   Sex                           1639 non-null   str
#  3   Age                           1571 non-null   float64
#  4   Weight (kg)                   1566 non-null   float64
#  5   Height (m)                    1578 non-null   float64
#  6   BMI                           1586 non-null   float64
#  7   Abdominal Circumference (cm)  1578 non-null   float64
#  8   Blood Pressure (mmHg)         1639 non-null   str
#  9   Total Cholesterol (mg/dL)     1571 non-null   float64
#  10  HDL (mg/dL)                   1557 non-null   float64
#  11  Fasting Blood Sugar (mg/dL)   1585 non-null   float64
#  12  Smoking Status                1639 non-null   str
#  13  Diabetes Status               1639 non-null   str
#  14  Physical Activity Level       1639 non-null   str
#  15  Family History of CVD         1639 non-null   str
#  16  Height (cm)                   1571 non-null   float64
#  17  Waist-to-Height Ratio         1563 non-null   float64
#  18  Systolic BP                   1578 non-null   float64
#  19  Diastolic BP                  1554 non-null   float64
#  20  Blood Pressure Category       1639 non-null   str
#  21  Estimated LDL (mg/dL)         1582 non-null   float64
#  22  CVD Risk Score                1610 non-null   float64
#  23  CVD Risk Level                1639 non-null   str
# dtypes: float64(14), str(10)
# memory usage: 307.4 KB

# %% [markdown]
# Ahora sabemos que la mayoría de los datos son de tipo float. Aún así, hay bastantes datos que son de tipo string. Adicionalmente, podemos ver que la mayoría de variables contienen registros nulos. La mayoría no son nulos, igualmente es una cantidad que se debe tener en cuenta.

# %% [markdown]
# Para conocer más sobre el tipo de información se va a acceder al diccionario de los datos:

# %%
diccionario_datos = pd.read_excel('./data/DiccPacientes.xlsx')
pd.set_option('display.max_colwidth', None)
diccionario_datos
# Out:
#                  Nombre Columna  Tipo de dato  \
# 0                     Patient ID       String
# 1                Date of Service         Date
# 2                            Sex       String
# 3                            Age      Integer
# 4                    Weight (kg)        Float
# 5                     Height (m)        Float
# 6                            BMI        Float
# 7   Abdominal Circumference (cm)        Float
# 8          Blood Pressure (mmHg)       String
# 9      Total Cholesterol (mg/dL)        Float
# 10                   HDL (mg/dL)        Float
# 11   Fasting Blood Sugar (mg/dL)        Float
# 12                Smoking Status      Boolean
# 13               Diabetes Status      Boolean
# 14       Physical Activity Level       String
# 15         Family History of CVD      Boolean
# 16                   Height (cm)        Float
# 17         Waist-to-Height Ratio        FLoat
# 18                   Systolic BP      Integer
# 19                  Diastolic BP      Integer
# 20       Blood Pressure Category       String
# 21         Estimated LDL (mg/dL)        Float
# 22                CVD Risk Score        Float
# 23                CVD Risk Level      String
#
#                                                                                               Comentarios
# 0                                                                              Identificador del paciente
# 1                                                                                    Fecha de la atención
# 2                                                                              Sexo (Femenino, Masculino)
# 3                                                                                                    Edad
# 4                                                                                                    Peso
# 5                                                                                                  Altura
# 6                                                                                 Índice de masa corporal
# 7                                                                                Circunferencia abdominal
# 8             Presión sanguínea, de la forma "<Presión arterial sistólica>/<Presión arterial diastólica>"
# 9                                                                                        Colesterol total
# 10                                                 Lipoproteína de alta densidad en el torrente sanguíneo
# 11                                                                  Nivel de azucar en la sangre en ayuno
# 12                                                          Booleano que indica si el paciente es fumador
# 13                                                        Booleano que indica si el paciente es diabético
# 14                                                       Nivel de actividad física (Alto, Moderado, Bajo)
# 15             Booleano que indica si en la familia han habido antecedentes de enfermedad cardio vascular
# 16                                                                                               Estatura
# 17                                             Cociente entre la circumferencia de la cintura y la altura
# 18                                                                             Presión arterial sistólica
# 19                                                                            Presión arterial diastólica
# 20  Categoría de presión sanguínea (Normal, Elevada, Hipertensión Etapa 1, Elevada, Hipertensión Etapa 2)
# 21                                                 Lipoproteína de baja densidad en el torrente sanguíneo
# 22                                                                                  Riesgo cardiovascular
# 23                                                 Nivel de riesgo cadiovascular (Alto, Intermedio, Bajo)

# %% [markdown]
# Combinando esto con la información que encontramos con datos.info(), podemos tener más contexto sobre cada variable diferente y entender por qué cada variable es el tipo que es. Además, acá se puede ver que hay algunas diferencias con el tipo de dato que sale en el diccionario vs el tipo que sale cuando se usa la función info().
#
# En específico, unas variables que dicen tipo string según info(), dice que son booleanas o date según el diccionario. En el caso de las que dicen float en info(), algunas son integer en el diccionario.

# %% [markdown]
# Para entender aún mejor, se va a usar la función describe():

# %%
datos.describe()
# Out:
#                Age  Weight (kg)   Height (m)          BMI  \
# count  1571.000000  1566.000000  1578.000000  1586.000000
# mean     46.803186    85.666006     1.757439    28.424744
# std      13.039479    21.712504     0.118012     7.309275
# min       6.134000    13.261000     1.371000     4.317000
# 25%      37.000000    67.100000     1.666500    22.600000
# 50%      46.000000    86.314000     1.760000    28.000000
# 75%      55.000000   104.801500     1.850000    33.963000
# max      89.420000   158.523000     2.146000    53.028000
#
#        Abdominal Circumference (cm)  Total Cholesterol (mg/dL)  HDL (mg/dL)  \
# count                   1578.000000                1571.000000  1557.000000
# mean                      91.538861                 199.043673    56.183558
# std                       13.427985                  59.388670    16.721702
# min                       49.542000                  -1.256000     0.008000
# 25%                       79.700000                 150.000000    42.000000
# 50%                       91.200000                 199.000000    56.000000
# 75%                      102.267250                 250.000000    70.000000
# max                      136.336000                 385.679000   110.315000
#
#        Fasting Blood Sugar (mg/dL)  Height (cm)  Waist-to-Height Ratio  \
# count                  1585.000000  1571.000000            1563.000000
# mean                    117.836860   175.770082               0.522440
# std                      32.379634    11.695880               0.085692
# min                      15.306000   136.498000               0.250000
# 25%                      92.000000   167.000000               0.453000
# 50%                     115.000000   176.000000               0.519000
# 75%                     139.000000   185.000000               0.582000
# max                     219.667000   214.394000               0.804000
#
#        Systolic BP  Diastolic BP  Estimated LDL (mg/dL)  CVD Risk Score
# count  1578.000000   1554.000000            1582.000000     1610.000000
# mean    125.632637     82.887536             113.235896       18.227281
# std      22.577463     15.503625              61.435291       10.767666
# min      49.914000     31.720000             -92.055000      -20.057000
# 25%     108.000000     71.000000              62.000000       15.150000
# 50%     125.000000     82.000000             112.000000       16.967000
# 75%     141.000000     93.000000             159.000000       18.900000
# max     202.711000    134.066000             317.314000      114.980000

# %% [markdown]
# Obervando los datos de esta manera permite generar conclusiones más específicas sobre las tendencias y otros elementos notables dentro de los datos. Estas son algunas de las conclusiones:
# - La mayoría de las personas en los datos tienden a ser adultos alrededor de los 45. Aún así, el rango va de 6 a 81.
# - Se puede ver que los pesos de las personas tienden a ser bastante alto. Esto puede indicar posibles hábitos de nutrición dentro de la población estudiada.
# - El BMI y el nivel de colesterol tiene sentido si se analiza junto a los pesos, que tienden a ser un poco altos.
# - Algunas variables tienen valores extraños. Por ejemplo, el colesterol total tiene al menos un valor negativo, lo cual es imposible. Lo mismo sucede con HDL y riesgo cardiovascular.
# - Existe altura tanto en metros como en centímetros. Esto es redundante y en algunos casos los datos se contradicen ligeramente.
#
# En general, los datos tiened a mostrar una población donde existe un alto riesgo cardiovascular por sobrepeso, reflejado por las tendencias altas en las variables que indican esto.
