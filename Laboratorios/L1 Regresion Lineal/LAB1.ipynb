# %% [markdown]
# # Exploración de los datos

# %% [markdown]
# ## 1. Importar las librerías

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn

# %% [markdown]
# ## 2. Cargar datos

# %% [markdown]
# Cargar los datos del csv

# %%
datos_pacientes = pd.read_csv('./data/Datos Lab 1.csv', )

# %% [markdown]
# Trabajar sobre una copia de los datos

# %%
datos = datos_pacientes.copy()

# %% [markdown]
# ## 3. Perfilamiento

# %% [markdown]
# Qué representan los datos compartidos

# %%
datos.head()
# Out:
#   Patient ID Date of Service Sex   Age  Weight (kg)  Height (m)     BMI  \
# 0   isDx5313      2023-11-08   M  44.0      114.300       1.720  38.600
# 1   LHCK2961             NaT   F  57.0       92.923       1.842  33.116
# 2   WjVn1699             NaT   F   NaN       73.400       1.650  27.000
# 3   dCDO1109      2022-04-18   F  35.0      113.300       1.780  35.800
# 4   pnpE1080             NaT   F  48.0      102.200       1.750  33.400
#
#    Abdominal Circumference (cm) Blood Pressure (mmHg)  \
# 0                       100.000                112/83
# 1                       106.315                101/91
# 2                        78.100                 90/74
# 3                        79.600                 92/89
# 4                       106.700                121/68
#
#    Total Cholesterol (mg/dL)  ...  Physical Activity Level  \
# 0                      228.0  ...                     High
# 1                      158.0  ...                     High
# 2                      135.0  ...                     High
# 3                      158.0  ...                 Moderate
# 4                      207.0  ...                      Low
#
#    Family History of CVD Height (cm) Waist-to-Height Ratio Systolic BP  \
# 0                      N     172.000                 0.581       112.0
# 1                      Y     184.172                 0.577       101.0
# 2                      N     165.000                 0.473        90.0
# 3                      Y     178.000                 0.447        92.0
# 4                      Y     175.000                 0.610       121.0
#
#   Diastolic BP  Blood Pressure Category  Estimated LDL (mg/dL)  \
# 0         83.0     Hypertension Stage 1                  121.0
# 1         91.0     Hypertension Stage 2                   57.0
# 2         74.0                   Normal                   45.0
# 3         89.0     Hypertension Stage 1                   94.0
# 4         68.0                 Elevated                  128.0
#
#    CVD Risk Score  CVD Risk Level
# 0          19.880            HIGH
# 1          16.833    INTERMEDIARY
# 2          12.600             LOW
# 3          14.920            HIGH
# 4          18.870            HIGH
#
# [5 rows x 24 columns]

# %% [markdown]
# En primer lugar corregimos el formato de las fechas

# %%
datos["Date of Service"] = pd.to_datetime(
    datos["Date of Service"],
    format="mixed",
    dayfirst=True,
    errors="coerce"
)
datos.head()
# Out:
#   Patient ID Date of Service Sex   Age  Weight (kg)  Height (m)     BMI  \
# 0   isDx5313      2023-11-08   M  44.0      114.300       1.720  38.600
# 1   LHCK2961      2024-03-20   F  57.0       92.923       1.842  33.116
# 2   WjVn1699      2021-05-27   F   NaN       73.400       1.650  27.000
# 3   dCDO1109      2022-04-18   F  35.0      113.300       1.780  35.800
# 4   pnpE1080      2024-11-01   F  48.0      102.200       1.750  33.400
#
#    Abdominal Circumference (cm) Blood Pressure (mmHg)  \
# 0                       100.000                112/83
# 1                       106.315                101/91
# 2                        78.100                 90/74
# 3                        79.600                 92/89
# 4                       106.700                121/68
#
#    Total Cholesterol (mg/dL)  ...  Physical Activity Level  \
# 0                      228.0  ...                     High
# 1                      158.0  ...                     High
# 2                      135.0  ...                     High
# 3                      158.0  ...                 Moderate
# 4                      207.0  ...                      Low
#
#    Family History of CVD Height (cm) Waist-to-Height Ratio Systolic BP  \
# 0                      N     172.000                 0.581       112.0
# 1                      Y     184.172                 0.577       101.0
# 2                      N     165.000                 0.473        90.0
# 3                      Y     178.000                 0.447        92.0
# 4                      Y     175.000                 0.610       121.0
#
#   Diastolic BP  Blood Pressure Category  Estimated LDL (mg/dL)  \
# 0         83.0     Hypertension Stage 1                  121.0
# 1         91.0     Hypertension Stage 2                   57.0
# 2         74.0                   Normal                   45.0
# 3         89.0     Hypertension Stage 1                   94.0
# 4         68.0                 Elevated                  128.0
#
#    CVD Risk Score  CVD Risk Level
# 0          19.880            HIGH
# 1          16.833    INTERMEDIARY
# 2          12.600             LOW
# 3          14.920            HIGH
# 4          18.870            HIGH
#
# [5 rows x 24 columns]
